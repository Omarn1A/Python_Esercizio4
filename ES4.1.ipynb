# %%
from sqlalchemy import create_engine
import dotenv
import os
import pandas as pd
dotenv.load_dotenv(override=True)
username = os.getenv('username')
password = os.getenv('password')
host = os.getenv('host')
dbname = os.getenv('dbname')

import pandas as pd
dbname = "AdventureWorksDW"
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)
query = """SELECT *
        FROM dimproduct
        """
df = pd.read_sql(query, db_engine)

# %%
df
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
df.shape
# Out:
# (606, 36)

# %%
df.columns
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
df.tail(1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
df.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 253         254          FR-R38B-58                   14.0
# 569         570          BK-T18Y-54                    3.0
# 240         241          FR-R92R-44                   14.0
# 138         139             LN-9161                    NaN
# 449         450             LT-T990                   33.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode            EnglishProductName  \
# 253                    LB                  CM     LL Road Frame - Black, 58
# 569                    LB                  CM       Touring-3000 Yellow, 54
# 240                    LB                  CM       HL Road Frame - Red, 44
# 138                  None                None                   Lock Nut 18
# 449                  None                None  Taillights - Battery-Powered
#
#                     SpanishProductName                      FrenchProductName  \
# ...

# %%
df.loc[:,'Color']
# Out:
# 0         NA
# 1         NA
# 2         NA
# 3         NA
# 4         NA
#        ...
# 601       NA
# 602       NA
# 603    Black
# 604    Black
# 605    Black
# Name: Color, Length: 606, dtype: object

# %%
df.loc[:,'Color'].unique()
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
df['Weight'].mean()
# Out:
# 56.1932269503546

# %%
df['Weight'].min()
# Out:
# 2.12

# %%
df['Weight'].max()
# Out:
# 1050.0

# %%
df['Weight'].describe()
# Out:
# count     282.000000
# mean       56.193227
# std       158.000652
# min         2.120000
# 25%         2.680000
# 50%        15.420000
# 75%        24.130000
# max      1050.000000
# Name: Weight, dtype: float64

# %%
filtro_peso=df['Weight']>100

# %%
df.loc[filtro_peso]
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 179         180             RM-M464                    NaN
# 180         181             RM-M692                    NaN
# 181         182             RM-M823                    NaN
# 182         183             RM-R436                    NaN
# 183         184             RM-R600                    NaN
# 184         185             RM-R800                    NaN
# 185         186             RM-T801                    NaN
# 412         413             FW-R623                   17.0
# 413         414             FW-R762                   17.0
# 414         415             FW-R820                   17.0
# 421         422             RW-R623                   17.0
# 422         423             RW-R762                   17.0
# 423         424             RW-R820                   17.0
# 500         501             RD-2308                    9.0
# 513         514             RB-9231                    6.0
# ...

# %%
df_over100=df.loc[filtro_peso]

# %%
df_over100.shape
# Out:
# (28, 36)

# %%
df['DealerPrice'].mean()
# Out:
# 448.5970597468353

# %%
df['DealerPrice'].describe()
# Out:
# count     395.000000
# mean      448.597060
# std       503.225071
# min         1.374000
# 25%        41.994000
# 50%       218.454000
# 75%       722.594900
# max      2146.962000
# Name: DealerPrice, dtype: float64

# %%
prodotti_blue=df['Color']=='Blue'
df_blue=df.loc[prodotti_blue]
df_blue.head()
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 219         220           HL-U509-B                   31.0
# 220         221           HL-U509-B                   31.0
# 221         222           HL-U509-B                   31.0
# 470         471           VE-C304-S                   25.0
# 471         472           VE-C304-M                   25.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode      EnglishProductName  \
# 219                  None                None  Sport-100 Helmet, Blue
# 220                  None                None  Sport-100 Helmet, Blue
# 221                  None                None  Sport-100 Helmet, Blue
# 470                  None                None         Classic Vest, S
# 471                  None                None         Classic Vest, M
#
#              SpanishProductName          FrenchProductName  StandardCost  \
# 219  Casco deportivo: 100, azul     Casque sport 100, bleu         12.03
# ...

# %%
df_blue['DealerPrice'].mean()
# Out:
# 516.0631785714286

# %%
prodotti_red=df['Color']=='Red'
prodotti_black=df['Color']=='Black'
df_red=df.loc[prodotti_red]
df_black=df.loc[prodotti_black]
df_rossonero=df.loc[prodotti_red | prodotti_black]
df_rossonero

# %%
df_red['DealerPrice'].mean()
# Out:
# 705.9632838709679

# %%
df_black['DealerPrice'].mean()
# Out:
# 474.8236875

# %%
df_rossonero['DealerPrice'].mean()
# Out:
# 550.2481873684211

# %%
taglia_42=df['Size']=='42'
peso_over10=df['Weight']>10
df_tagliapeso=df.loc[taglia_42 & peso_over10]

# %%
df_tagliapeso['DealerPrice'].describe()
# Out:
# count      12.000000
# mean     1060.343267
# std       599.030160
# min       323.994000
# 25%       565.620375
# 50%      1125.026450
# 75%      1380.744000
# max      2039.994000
# Name: DealerPrice, dtype: float64

# %%
df_tagliapeso['DealerPrice'].max()
# Out:
# 2039.994

# %%
taglia_42=df['Size']=='42'
peso_over10=df['Weight']>10
prodotti_silver=df['Color']=='Silver'
df_tagliapesocolore=df.loc[taglia_42 & peso_over10 & prodotti_silver] 
print(df_tagliapesocolore)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 344         345          BK-M82S-42                    1.0
# 353         354          BK-M68S-42                    1.0
# 354         355          BK-M68S-42                    1.0
# 588         589          BK-M38S-42                    1.0
# 591         592          BK-M18S-42                    1.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode         EnglishProductName  \
# 344                    LB                  CM    Mountain-100 Silver, 42
# 353                    LB                  CM    Mountain-200 Silver, 42
# 354                    LB                  CM    Mountain-200 Silver, 42
# 588                    LB                  CM  Mountain-400-W Silver, 42
# 591                    LB                  CM    Mountain-500 Silver, 42
#
#                         SpanishProductName      FrenchProductName  \
# 344             Montaña: 100, plateada, 42     VTT 100 argent, 42
# ...

# %%
df_tagliapesocolore.loc[:, 'EnglishProductName':'StandardCost']
# Out:
#             EnglishProductName                     SpanishProductName  \
# 344    Mountain-100 Silver, 42             Montaña: 100, plateada, 42
# 353    Mountain-200 Silver, 42             Montaña: 200, plateada, 42
# 354    Mountain-200 Silver, 42             Montaña: 200, plateada, 42
# 588  Mountain-400-W Silver, 42  Montaña: 400 para mujer, plateada, 42
# 591    Mountain-500 Silver, 42             Montaña: 500, plateada, 42
#
#          FrenchProductName  StandardCost
# 344     VTT 100 argent, 42       1912.15
# 353     VTT 200 argent, 42       1117.86
# 354     VTT 200 argent, 42       1265.62
# 588  VTT 400 -W argent, 42        419.78
# 591     VTT 500 argent, 42        308.22

# %%
coda=df.tail(20)

# %%
p_standard=coda['StandardCost']

# %%
p_dealer=coda['DealerPrice']

# %%
differenza=p_standard - p_dealer

# %%
print(differenza)
# Out:
# 586   -41.914
# 587   -41.914
# 588   -41.914
# 589   -41.914
# 590   -30.774
# 591   -30.774
# 592   -30.774
# 593   -30.774
# 594   -30.774
# 595   -29.414
# 596   -29.414
# 597   -29.414
# 598   -29.414
# 599   -29.414
# 600    -8.424
# 601   -15.794
# 602   -18.954
# 603    19.656
# 604    19.656
# 605    19.656
# dtype: float64

# %%
#Il prezzo Standard è sempre maggiore tranne che per gli ultimi tre prodotti
